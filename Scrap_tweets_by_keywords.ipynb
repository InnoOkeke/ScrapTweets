# %%
import tweepy
import pandas as pd

# %%
import tweepy
import pandas as pd

# API KEY=############ SECRET= ############ Acces Token= ################## Access token secret= ###########
consumer_key= '############consumer_secret= '#################access_token= '##########access_token_secret= '############
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

text_query = 'Kidnapping'
count = 150
try:
 # Creation of query method using parameters
 tweets = tweepy.Cursor(api.search,q=text_query).items(count)
 
 # Pulling information from tweets iterable object
 tweets_list = [[tweet.created_at, tweet.id, tweet.text] for tweet in tweets]
 
 # Creation of dataframe from tweets list
 # Add or remove columns as you remove tweet information
 tweetsy_df = pd.DataFrame(tweets_list)
 
except BaseException as e:
    print('failed on_status,',str(e))
    time.sleep(3)

# %%
tweetsy_df
# Out:
#                       0                    1  \
# 0   2021-01-13 11:27:44  1349317200063193093
# 1   2021-01-13 11:27:38  1349317175501152258
# 2   2021-01-13 11:27:38  1349317174620377088
# 3   2021-01-13 11:27:25  1349317122170744832
# 4   2021-01-13 11:27:21  1349317104600801281
# ..                  ...                  ...
# 145 2021-01-13 11:03:43  1349311156163379200
# 146 2021-01-13 11:03:07  1349311005986226177
# 147 2021-01-13 11:02:45  1349310914563076097
# 148 2021-01-13 11:02:42  1349310899635544067
# 149 2021-01-13 11:02:28  1349310843398336512
#
#                                                      2
# 0    @bigboichloe it's not abt kink-shaming.  there...
# 1    RT @CharlotteAlter: AOC just said on her Insta...
# 2    RT @shashwhatnow: TW// promoting kidnapping/r*...
# 3    RT @CharlotteAlter: AOC just said on her Insta...
# 4    @GeraldoRivera @LizCheney So assaulting women,...
# ..                                                 ...
# 145  RT @dunekhaal: Time for another tweet in WTF?\...
# 146  RT @shashwhatnow: TW// promoting kidnapping/r*...
# 147  RT @PeachieRad: ...so it took y’all seeing Bel...
# 148  RT @CharlotteAlter: AOC just said on her Insta...
# 149  RT @bulamabukarti: Recent stories from the nor...
#
# [150 rows x 3 columns]

# %%
tweetsy_df.to_csv(r'C:\Users\CSSL\Documents\Intelligence Report\tweetsy_df.csv')
