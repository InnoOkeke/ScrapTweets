# %%
pip install tweepy
# Out:
# Collecting tweepy
#   Downloading tweepy-3.10.0-py2.py3-none-any.whl (30 kB)
# Collecting requests-oauthlib>=0.7.0
#   Downloading requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: six>=1.10.0 in c:\users\cssl\anaconda3\lib\site-packages (from tweepy) (1.14.0)
# Requirement already satisfied: requests[socks]>=2.11.1 in c:\users\cssl\anaconda3\lib\site-packages (from tweepy) (2.22.0)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.1.0-py2.py3-none-any.whl (147 kB)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\cssl\anaconda3\lib\site-packages (from requests[socks]>=2.11.1->tweepy) (1.25.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\cssl\anaconda3\lib\site-packages (from requests[socks]>=2.11.1->tweepy) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\cssl\anaconda3\lib\site-packages (from requests[socks]>=2.11.1->tweepy) (2019.11.28)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\cssl\anaconda3\lib\site-packages (from requests[socks]>=2.11.1->tweepy) (2.8)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6; extra == "socks" in c:\users\cssl\anaconda3\lib\site-packages (from requests[socks]>=2.11.1->tweepy) (1.7.1)
# Installing collected packages: oauthlib, requests-oauthlib, tweepy
# Successfully installed oauthlib-3.1.0 requests-oauthlib-1.3.0 tweepy-3.10.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import tweepy
import pandas as pd


consumer_key= '################consumer_secret= '############access_token= '#############access_token_secret= '##############
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

username = 'Bulwark_Intel'
count = 150
try:     
 # Creation of query method using parameters
 tweets = tweepy.Cursor(api.user_timeline,id=username).items(count)
 
 # Pulling information from tweets iterable object
 tweets_list = [[tweet.created_at, tweet.id, tweet.text] for tweet in tweets]
 
 # Creation of dataframe from tweets list
 # Add or remove columns as you remove tweet information
 tweets_df = pd.DataFrame(tweets_list)
except BaseException as e:
      print('failed on_status,',str(e))
      time.sleep(3)

# %%
tweets_df
# Out:
#                       0                    1  \
# 0   2021-01-13 10:52:53  1349308430998269952
# 1   2021-01-13 10:25:05  1349301432894316544
# 2   2021-01-12 20:20:42  1349088938376441856
# 3   2021-01-12 20:20:41  1349088935721496576
# 4   2021-01-12 20:20:41  1349088932626051075
# ..                  ...                  ...
# 145 2020-12-09 08:49:38  1336593839780401153
# 146 2020-12-09 08:03:40  1336582269377662976
# 147 2020-12-09 08:03:39  1336582267574038529
# 148 2020-12-07 12:23:05  1335922781276528640
# 149 2020-12-07 12:18:01  1335921505889382403
#
#                                                      2
# 0    Ongoing Protest, 11:51hrs, Lagos State, Januar...
# 1    Traffic Advisory, 11:23hrs, Lagos state, Janua...
# 2    All Iyana Oworosoki bound traffic from Lagos I...
# 3    All traffic from Ogudu, Alapere, and Gbagada g...
# 4    Update: Traffic Advisory/Road Closure, 21:20hr...
# ..                                                 ...
# 145  Kidnap Incident, 09:48hrs, Taraba State, Decem...
# 146  ....Poor remuneration for health workers and a...
# 147  Planned Strike, 09:00hrs, Zamfara State, Decem...
# 148  Ongoing #EndSars Protest, 13:22hrs, Osun State...
# 149  Update: Ongoing #EndSars Protest, 13:15hrs, La...
#
# [150 rows x 3 columns]

# %%
tweets_df.to_csv(r'C:\Users\CSSL\Documents\Intelligence Report\tweets_df.csv')
